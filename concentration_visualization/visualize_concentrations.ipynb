# %%
import pandas as pd
import seaborn as sb

# %%
# for some reason, reading the target.csv only works when using the absolute path, not the relative path
# since the relative path is working for other files in this directory, I don't know how to fix this
# target = pd.read_csv('target.csv')
# sb.heatmap(target)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [29], line 1
# ----> 1 target = pd.read_csv('target.csv')
#       2 sb.heatmap(target)
#
# File ~/Library/CloudStorage/OneDrive-Stanford/2022-2023 - Senior/Fall 2022/CS 221/Axon-Guidance-Simulation/axon-env/lib/python3.8/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/Library/CloudStorage/OneDrive-Stanford/2022-2023 - Senior/Fall 2022/CS 221/Axon-Guidance-Simulation/axon-env/lib/python3.8/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
# ...

# %%
netrin = pd.read_csv('netrin.csv')
sb.heatmap(netrin)
# Out:
# <AxesSubplot:>

# %%
shh = pd.read_csv('shh.csv')
sb.heatmap(shh)
# Out:
# <AxesSubplot:>

# %%
slit = pd.read_csv('slit.csv')
sb.heatmap(slit)
# Out:
# <AxesSubplot:>
